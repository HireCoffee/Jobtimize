# %%
# %run ../Jobtimize/scrapindeed.py

# %%
indeed = IndeedScrap(["Data Analyst rennes"], ["FR"])

# %%
indeed
# Out:
# [{'country': 'FR',
#   'url': 'https://www.indeed.com/viewjob?jk=26dd13f600815706',
# ...
